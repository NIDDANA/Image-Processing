# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pic  = cv2.imread("G:/c1.jpg")
cv2.imshow("image", pic)

cv2.waitKey(0)

plt.imshow(pic)
plt.show()

# %%
gray = cv2.cvtColor(pic, cv2.COLOR_BGR2GRAY)

threshold, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
cv2.imshow("simple thrshold", thresh )
cv2.imshow("gray", gray)
cv2.waitKey(0)
# Out:
# -1

# %%
plt.imshow(gray)
plt.show()

# %%
plt.imshow(thresh)

plt.show()

# %%
#inverse thresholding
thresho, thresh_inv = cv2.threshold(gray, 100, 56, cv2.THRESH_BINARY_INV)
cv2.imshow("inver binary", thresh_inv)
cv2.imshow("simple thrshold", thresh )
cv2.imshow("gray", gray)
cv2.waitKey(0)
# Out:
# -1

# %%
#adaptive thesholding
adaptive_thresh = cv2.adaptiveThreshold(gray, 150,
                                        cv2.ADAPTIVE_THRESH_MEAN_C,
                                        cv2.THRESH_BINARY,
                                        11, 3
                                       )

adaptive_thres = cv2.adaptiveThreshold(gray, 250,
                                        cv2.ADAPTIVE_THRESH_MEAN_C,
                                        cv2.THRESH_BINARY,
                                        11, 3
                                       )

cv2.imshow("adaptive threshold", adaptive_thresh)
cv2.imshow("adaptive threshol", adaptive_thres)

cv2.waitKey(0)
# Out:
# -1

# %%
plt.imshow(adaptive_thresh)
plt.title("Adaptive _threshold")
plt.show()

# %%
adaptive_thr = cv2.adaptiveThreshold(gray, 10,
                                        cv2.ADAPTIVE_THRESH_MEAN_C,
                                        cv2.THRESH_BINARY,
                                        11, 9
                                       )
adaptive_thre = cv2.adaptiveThreshold(gray, 100,
                                       cv2.ADAPTIVE_THRESH_MEAN_C,
                                        cv2.THRESH_BINARY,
                                        11, 7
                                       )
adaptive_thres = cv2.adaptiveThreshold(gray, 200,
                                        cv2.ADAPTIVE_THRESH_MEAN_C,
                                        cv2.THRESH_BINARY,
                                        11, 5
                                       )
adaptive_thresh = cv2.adaptiveThreshold(gray, 250,
                                        cv2.ADAPTIVE_THRESH_MEAN_C,
                                        cv2.THRESH_BINARY,
                                        11, 1
                                       )
cv2.imshow("adaptive threshold 1", adaptive_thr)
cv2.imshow("adaptive threshold 2", adaptive_thre)
cv2.imshow("adaptive threshold 3", adaptive_thres)
cv2.imshow("adaptive threshold 4", adaptive_thresh)
cv2.waitKey(0)
# Out:
# -1
